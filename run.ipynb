# %% [markdown]
# # Per-participant EEG sentiment model
# Run the cells in order. The first one sets everything up; the second asks for your data folders and where to save.

# %%
# This per-participant CNN is tiny -> CPU is plenty and dodges Colab's flaky GPU.
# (GPU only matters for the later BERT notebooks, not this one.)
# If you already ran on GPU in this session, do Runtime -> Restart session first.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"   # force CPU; must be set before TF imports

from per_participant_eeg import run

trt_dir     = '/content/drive/MyDrive/Thesis/Data/TRT_Total'
labels_csv  = '/content/drive/MyDrive/Thesis/Data/teco_sentiment_labels_task1.csv'
out_dir     = '/content/drive/MyDrive/Thesis/Results/reproduce_yaser_codes/eegonly/v1'

results = run(trt_dir, labels_csv, out_dir)

# %%
# This per-participant CNN is tiny -> CPU is plenty and dodges Colab's flaky GPU.
# (GPU only matters for the later BERT notebooks, not this one.)
# If you already ran on GPU in this session, do Runtime -> Restart session first.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"   # force CPU; must be set before TF imports

from per_participant_eeg import run

trt_dir     = '/content/drive/MyDrive/Thesis/Data/TRT_Total'
labels_csv  = '/content/drive/MyDrive/Thesis/Data/teco_sentiment_labels_task1.csv'
out_dir     = '/content/drive/MyDrive/Thesis/Results/reproduce_yaser_codes/eegonly/v1'

results = run(trt_dir, labels_csv, out_dir)

# %%
results.round(3)
